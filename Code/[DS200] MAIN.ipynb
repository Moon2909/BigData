# %% [markdown]
# Link TỔNG HỢP: https://drive.google.com/drive/folders/1_AXzPfVs9Ul1dyasf7VVb7mQWEQS21GH?usp=drive_link

# %% [markdown]
# # **1. Library**

# %%
# !pip install snorkel
# Out:
# Collecting snorkel
#   Downloading snorkel-0.9.9-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 1.4 MB/s eta 0:00:00
# Collecting munkres>=1.0.6 (from snorkel)
#   Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.22.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.10.1)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.5.3)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (4.65.0)
# Requirement already satisfied: scikit-learn>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from snorkel) (1.2.2)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from snorkel) (2.0.1+cu118)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from snorkel) (2.12.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from snorkel) (3.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->snorkel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->snorkel) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.2->snorkel) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.2->snorkel) (3.2.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.56.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->snorkel) (0.40.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2.0->snorkel) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.2.0->snorkel) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.2.0->snorkel) (16.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->snorkel) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->snorkel) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->snorkel) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.2.0->snorkel) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->snorkel) (3.2.2)
# Installing collected packages: munkres, snorkel
# Successfully installed munkres-1.1.4 snorkel-0.9.9

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

import torch
import copy
import random

import lightgbm as lgb
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Paths**

# %%
path = '/content/drive/MyDrive/Học kì 6/DS200/Dataset/'
path_split = '/content/drive/MyDrive/Học kì 6/DS200/Dataset/Split/'
path_repr = '/content/drive/MyDrive/Học kì 6/DS200/Dataset/Representation/'
path_uad = '/content/drive/MyDrive/Học kì 6/DS200/Dataset/UAD/'
path_feature = '/content/drive/MyDrive/Học kì 6/DS200/Dataset/Feature/'

# %% [markdown]
# # **2. Dataset**
#
# - Tải dữ liệu từ: https://finance.yahoo.com/quote/AAPL/history?period1=1104537600&period2=1689465600&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true
#  + Dữ liệu ban đầu: 21792 rows × 6 columns
# - Code phân tích, tiền xử lý, điền khuyết: https://colab.research.google.com/drive/1RMtoTQs8yhZfTfkqwUqeIcP3OT0pSPZq?usp=drive_link
#  + Xử lý giá trị khuyết: Dựa trên kết quả dữ liệu ngày: https://colab.research.google.com/drive/1YbtOEa8evpQJMKkODaxi5RSXTc4QxX7N?usp=sharing
#  + Kết quả dữ liệu sau tiền xử lý : 24000 x 6  (dữ liệu trong 5 tuần)

# %% [markdown]
# ## 2.1. **Create Anomaly (Sử dụng trong quá trình Human Labeling)**
#
# Không chạy lại

# %%
'''
Tạo Anomaly: (Thay thế human trong phần dưới)
 - Dựa trên cơ sở thống kê phổ biến để xác định các giá trị bất thường dựa trên giá trị
trung bình và độ lệch chuẩn của một phân phối dữ liệu. Cụ thể, đây là một phương pháp
sử dụng phân phối chuẩn (normal distribution) hoặc phân phối Gaussian.
  => Tính toán giá trị trung bình và độ lệch chuẩn cho dữ liệu 10 ngày gần nhất,
  sau đó so sánh giá trị của mỗi cột với giá trị trung bình và độ lệch chuẩn đó
   => Số điểm bất thường được ghi nhận: 4381

Từ file Anomaly này sẽ tiến hành chia tập 6:4
'''

'''
Bước thực hiện tạo anomaly:
 - Xác định số ngày trong khoảng thời gian nhất định (10 ngày gần nhất)
 - Xác định ngưỡng cho giao dịch bất thường (lớn hơn 2 độ lệch chuẩn)
 - Xác định các cột dữ liệu cần xét
 - Tạo cột nhãn mới để lưu trữ kết quả gán nhãn
 - Tạo các cột mới để lưu trữ kết quả (giá trị trung bình, phương sai (độ lệch chuẩn))
 - Xác định giao dịch bất thường: Vượt qua ngưỡng bất thường trong tất cả các cột để gán nhãn là điểm bất thường
 - Lưu dữ liệu đã gán nhãn vào file CSV
'''

data = pd.read_csv(path+'Data_processed.csv')
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')

time_window = 5*16*60 # 1tuan
threshold = 3
columns_to_check = ['Open', 'High', 'Low', 'Close', 'Volume']

df = data[columns_to_check].copy()
df['Anomaly'] = 0

for column in columns_to_check:
    df[column + '_mean'] = df[column].rolling(window=time_window, min_periods=1).mean()
    df[column + '_std'] = df[column].rolling(window=time_window, min_periods=1).std()

for index, row in df.iterrows():
    for column in columns_to_check:
        column_mean = row[column + '_mean']
        column_std = row[column + '_std']
        value = row[column]

        if value > column_mean + (threshold * column_std) or value < column_mean - (threshold * column_std):
            df.at[index, 'Anomaly'] = 1

columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'Anomaly']

data_anomaly = df[columns].copy()
#data_anomaly.to_csv(path+'Data_Anomaly.csv')

print("Số điểm bất thường được ghi nhận:", data_anomaly['Anomaly'].sum())
print("Tỷ lệ số điểm bất thường trong dữ liệu:", (data_anomaly['Anomaly'].sum() / len(data_anomaly))*100)
# Out:
# Số điểm bất thường được ghi nhận: 330
# Tỷ lệ số điểm bất thường trong dữ liệu: 1.375

# %% [markdown]
# ## 2.2. **Chia train:test (6:4)**
#
# Không chạy lại

# %%
# Split
def split_data(data):
  X = data.drop('Anomaly', axis=1)
  y = data['Anomaly']
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42, stratify=y)
  return X_train, X_test, y_train, y_test

"""train_data, test_data, train_labels, test_labels = split_data(data_anomaly)
# Save
train_data.to_csv(path_split+"train_data.csv")
train_labels.to_csv(path_split+"train_labels.csv", index = False)
test_data.to_csv(path_split+"test_data.csv")
test_labels.to_csv(path_split+"test_labels.csv", index = False)"""

# %% [markdown]
# # **3. LEIAD**

# %% [markdown]
# ## 3.1. **Các Class**

# %% [markdown]
# ### 3.1.1. Weak Supervision Module

# %%
class WeakSupervisionModel():
    def __init__(self):
            from snorkel.labeling.model import LabelModel
            self.model = LabelModel(cardinality=2, verbose=False)

    def fit(self, LFs, alpha=0.01, seed=123):
            LFs = np.array(LFs)
            # Snorkel
            self.model.fit(
                L_train=np.array(LFs),
                class_balance=np.array([1-alpha, alpha]),
                lr=0.001,
                n_epochs=200,
                seed=seed,
                optimizer = 'adam',
                progress_bar = False
            )
    def pred_pos(self, LFs):
        ''' Dự đoán xác suất thuộc lớp dương (positive class) cho các mẫu dữ liệu trong tập LFs '''
        LFs_np = np.array(LFs)
        pred = self.model.predict_proba(LFs_np) # xác xuất neg sẽ ở đầu, và pos ở sau
        proba = pred[:, 1] # chọn cột thứ 2 trong mảng (cột pos)
        proba = np.array(pd.DataFrame(proba).fillna(0))
        return pd.DataFrame(proba, index=LFs.index, columns=['score'])

    def gen_fake_label(self, proba_pos, proba_neg, thres_pos, thres_neg):
        fake_label = proba_pos.copy()
        fake_label.columns = ['Label']
        fake_label[:] = -1
        fake_label[proba_pos.score >= thres_pos] = 1
        fake_label[proba_neg.score <= thres_neg] = 0

        return fake_label

    def thres_adaptive_decend(self, num_LF, score):
        thres = 99.7
        return np.percentile(score, thres)

# %% [markdown]
# ### 3.1.2. End Model

# %%
class LightGBM():
    def __init__(self, **params):
        self.param = {
            'num_leaves': 200,
            'objective': 'binary',
            # 'metric':'average_precision',
            'verbosity': -1,
            'is_unbalance': True,
            # 'device': 'gpu'
        }
        self.param.update(params)

    def train(self, data, label, weight=None):
        data = np.array(data)
        label = np.array(label)

        X_train, X_test, y_train, y_test = train_test_split(
        data, label, test_size = 0.2, random_state = 0)

        train_data = lgb.Dataset(X_train, label=y_train)
        valid_data = lgb.Dataset(X_test, label=y_test)

        train_data = lgb.Dataset(data, label=label, weight=weight) # sử dụng trọng số để cân =
        # print(self.param)
        self.model = lgb.train(
            self.param,
            train_data,
            valid_sets=[valid_data],
            early_stopping_rounds=50,
            verbose_eval=False
        )

    def predict(self, data):
        '''
        Giá trị dự đoán này thường là các số thực trong khoảng từ 0 đến 1,
        biểu thị xác suất mẫu thuộc vào lớp tích cực (positive class) của mô hình.
        '''
        data = np.array(data)
        pred = self.model.predict(data)

        return pred

# %% [markdown]
# ### 3.1.3. Active Learning

# %%
class ActiveLearning():
    '''
    Học chủ động là một phương pháp trong đó một hệ thống tự động chọn các điểm dữ liệu
    cần được người dùng đánh nhãn để cải thiện mô hình.
    => thực hiện học chủ động và chọn các điểm dữ liệu cần được đánh nhãn tiếp theo.
    (Tính toán các giá trị không chắc chắn dựa trên các thông số đầu vào)

    '''
    def __init__(self, anomaly_prob_init):
        self.index_list = anomaly_prob_init.index.tolist()
        # init uncerntainty: các giá trị không chắc chắn của dữ liệu
        self.uncertainty = pd.concat([anomaly_prob_init for _ in range(5)], axis=1)
        self.uncertainty[:] = 0
        self.uncertainty.columns = ["lf_dis", "lf_abs", "uncertainty_s", "diversity", "anomaly_prob_init"]
        # Anomaly probability of UADs
        self.uncertainty['anomaly_prob_init'] = anomaly_prob_init
        # Edit here if you want to remove some metrics [1, 0.5, 0.5, 1, 0.2]
        self.weight = pd.DataFrame(pd.Series([1, 0.5, 0.5, 1, 0.2], index=self.uncertainty.columns, name=0))

    # Tính toán các giá trị không chắc chắn dựa trên các thông số đầu vào
    def cal_uncertainty(self, dnn_pred, LFs, ts2vec, golden_labels):
        # dnn_pred = limit_min_max_normalize(dnn_pred, limit=10)
        pred_1 = LFs.replace(-1,0).sum(axis=1)
        pred_0 = LFs.replace(1,-1).replace(0,1).replace(-1,0).sum(axis=1)
        pred_anomaly = pred_1/(pred_1+pred_0)
        pred_anomaly = pred_anomaly.fillna(0)
        # Agreement of labeling functions
        self.uncertainty["lf_dis"] = -np.array(pred_anomaly * np.log(pred_anomaly + 1e-20) + (1 - pred_anomaly) * np.log(1 - pred_anomaly + 1e-20))
        # Hit time with labeling functions
        self.uncertainty["lf_abs"] = np.log(-LFs.where(LFs == -1, other = 0).sum(axis=1) + 1)
        # Uncertainty of the supervised end model
        self.uncertainty["uncertainty_s"] = -np.array(dnn_pred * np.log(dnn_pred + 1e-20) + (1 - dnn_pred) * np.log(1 - dnn_pred + 1e-20))
        # Diversity
        self.uncertainty["diversity"] = ts2vec.cal_diversity(golden_labels)

    def get_next_sample(self, golden_labels, ts_num=1, len_padding=None):

        uncertainty_norm = min_max_normalize(self.uncertainty)
        uncertainty_weighted = uncertainty_norm.dot(self.weight)

        uncertainty_weighted_sort = uncertainty_weighted.loc[golden_labels.Label == -1]
        uncertainty_weighted_sort = uncertainty_weighted_sort.sort_values(by=0, ascending=False)



        top_k = uncertainty_weighted_sort.index[:ts_num].tolist()
        # print(top_k)
        return top_k

    def get_next_sample_random(self, golden_labels, ts_num=1, len_padding=None, empty_keys = None):

        random.shuffle(self.index_list)
        top_k = self.index_list[:ts_num]
        return top_k

# %% [markdown]
# ### 3.1.4. Labeling Function Generation

# %%
class LFGenerator():
    '''
    Được sử dụng để tạo các Labeling Functions (LFs)
    dựa trên mô hình được chọn, có thể là ts2vec hoặc dnn_features.
    all_reper: biến để lưu trữ các biểu diễn (representations) của tập dữ liệu huấn luyện (kiểu các feature đầu vào)
    '''
    def __init__(self, model='ts2vec'):
        # load all repr
        self.model = model

        if model=='ts2vec':
            self.all_repr = load_reper(path_repr)
            l2 = np.sqrt((self.all_repr**2).sum(axis=1))
            self.all_repr_norm = self.all_repr.div(l2, axis=0)
            self.thr = 8

        elif model=='dnn_features':
            self.all_repr = load_feature(path_feature)
            self.thr = 8

    def predict(self, sample_index):
        sample_repr = self.all_repr.iloc[sample_index]

        if self.model=='dnn_features':
            # inner product
            distance = np.dot(self.all_repr, sample_repr)
            pred = self.gen_lf(distance)

        elif self.model=='ts2vec':
            # L1 Distance with norm
            sample_repr_norm = np.divide(sample_repr, np.sqrt((sample_repr**2).sum()))
            distance = np.abs(self.all_repr_norm - sample_repr).sum(axis=1)
            pred = self.gen_lf(distance)

        return pred

    def get_repr(self, index):
        return pd.DataFrame(self.all_repr).iloc[index]

    def gen_lf(self, distance):
        thr = np.mean(distance) - self.thr * np.std(distance)
        pred = distance < thr

        pred_int = np.zeros_like(pred).astype(int)
        pred_int[pred==True] = 1
        pred_int[pred==False] = -1
        return pred_int

    def cal_diversity(self, golden_labels):
        num_golden_labels = (golden_labels != -1).sum().item()
        if num_golden_labels:
            golden_labels_sort = golden_labels.sort_values(by='Label', ascending=False)
            index_list = golden_labels_sort[:num_golden_labels].index
            labeled_repr = self.all_repr.loc[index_list]

            # diversity calculation controled under 1 min
            if num_golden_labels > 1000:
                labeled_repr = labeled_repr.sample(1000)

            # use pytorch to accelerate
            all_repr = torch.from_numpy(np.array(self.all_repr)).to(torch.float)
            labeled_repr = torch.from_numpy(np.array(labeled_repr).transpose()).to(torch.float)
            diversity = 1-torch.mm(all_repr, labeled_repr).sum(axis=1)/num_golden_labels
            diversity = np.array(diversity)
        else:
            diversity = np.zeros_like(golden_labels)
        return diversity

# %% [markdown]
# ## 3.2.**Các thông số và hàm lẻ**

# %%
seed = 123

use_uad = True
use_t2v = True
use_stat = True

ABSTAIN = -1
n_iter = 0
n_interact = 0

# Hyper-parameters
WS_RATIO = 0.1
LEN_PADDING = 50 #200
ANOMALY_PERCENTAGE = 1
ZERO = 0.00000001
UAD_POS_THR = 0.8
UAD_NEG_THR = 0.2
N_A_RATIO = 100/ANOMALY_PERCENTAGE
NORMAL_PERCENTAGE = 100 - ANOMALY_PERCENTAGE

# %%
def load_data(path_split):
    train_data = pd.read_csv(path_split + "train_data.csv")
    train_labels = pd.read_csv(path_split + "train_labels.csv")
    return train_data, train_labels

def load_uad_score(path_uad):
    uad_score = pd.read_csv(path_uad + "train_score_uad.csv")
    return uad_score

def load_feature(path_feature):
   train_features = pd.read_csv(path_feature + "train_features.csv")
   train_features = train_features.drop(columns='Date')
   object_cols = train_features.select_dtypes(include='object').columns
   for col in object_cols:
    train_features[col] = train_features[col].str.replace('[','').str.replace(']','')
    train_features[col] = pd.to_numeric(train_features[col], errors='coerce')
   return train_features

def load_reper(path_repr):
    train_repr = pd.read_csv(path_repr + "train_repr.csv")
    train_repr = train_repr.drop(columns=	'Unnamed: 0')
    return train_repr

# %%
def min_max_normalize(data):
    min_ = data.min()
    max_ = data.max()
    data = (data - min_) / (max_ - min_ + ZERO)
    return data

# %%
def adjust_fake_label(fake_label, golden_labels):
    fake_label.loc[golden_labels['Label'] == 1] = 1
    fake_label.loc[golden_labels['Label'] == 0] = 0
    return fake_label

def fake_labels(LFs, ws_score, ws_model, index_pd, golden_labels, n_iter, N_SAMPLE, ANOMALY_PERCENTAGE, WS_RATIO, N_A_RATIO):
    num_ano_gol = (golden_labels.Label==1).sum()

    if mv_flag == False:
        pos_thres = max(num_ano_gol * 50 / N_SAMPLE, ANOMALY_PERCENTAGE * WS_RATIO)

        # ws_thres_pos và ws_thres_neg được tính toán dựa trên weak supervision model.
        ws_thres_pos = np.percentile(ws_score, 100 - pos_thres)
        ws_thres_neg = np.percentile(ws_score, pos_thres * N_A_RATIO)
        if ws_thres_pos == 1 or ws_thres_neg == 0:
            fake_labels.mv_flag = True
        fake_label = ws_model.gen_fake_label(proba_pos=ws_score, proba_neg=ws_score, thres_pos=ws_thres_pos, thres_neg=ws_thres_neg)
    else:
        num_ano_ws = int(max(2 * num_ano_gol, N_SAMPLE * ANOMALY_PERCENTAGE * WS_RATIO / 100))
        num_nor_ws = int(num_ano_ws * N_A_RATIO)
        sorted_pd = pd.DataFrame((LFs == 1).sum(axis=1) - (LFs == 0).sum(axis=1)).sort_values(by=0)
        ano_id = sorted_pd[-num_ano_ws:].index
        normal_id = sorted_pd[:num_nor_ws].index
        fake_label = index_pd.copy()
        fake_label.loc[ano_id] = 1
        fake_label.loc[normal_id] = 0

    fake_label = adjust_fake_label(fake_label, golden_labels)

    return fake_label

# %%
def limit_min_max_normalize(data, limit):
    min_ = np.percentile(data, limit)
    max_ = np.percentile(data, 100-limit)
    data[data>max_] = max_
    data[data<min_] = min_
    data = (data - min_) / (max_ - min_ + ZERO)
    return data

# %% [markdown]
# ## 3.3.**Unsupervised Anomaly Detector (UAD)**
#
# Xây dựng Label Functions (LFs): Sử dụng các phương pháp phát hiện lỗi không giám sát (i-Forest, SR, LOF, RC-Forest và Luminol) để tạo thành các Label Function ban đầu. - Các score predict
#
# Được thực hiện trong file: https://colab.research.google.com/drive/193wgseqMNENb7bmlxLDElgwSVIKLCJ8j?usp=drive_link

# %%
train_data, train_labels = load_data(path_split)
uad_scores = load_uad_score(path_uad)

# %%
# Phục vụ trong quá trình lặp
train_features = load_feature(path_feature)

# %%
uad_score = uad_scores.drop(columns='Date').copy()
anomaly_prob_init = uad_score.sum(axis=1)*0.2 #Tổng của các điểm dữ liệu từ các mô hình UAD và nhân với 0.2.

uad_labels = uad_score.copy()
uad_labels[:] = -1

# Labeling Function này được sử dụng dựa trên luật về ngưỡng (Label ban đầu)
for method in uad_score.columns:
    uad_score[method] = min_max_normalize(uad_score[method])
uad_labels[uad_score > UAD_POS_THR] = 1
uad_labels[uad_score < UAD_NEG_THR] = 0
LFs = uad_labels.copy().astype(int)
# Tính toán nhãn ts2vec dưới dạng UAD - Chưa biết tại sao phải làm vây => chưa thực hiện

# %%
anomaly_prob_init
# Out:
# 0        0.299859
# 1        0.183967
# 2        0.193531
# 3        0.208326
# 4        0.208251
#            ...
# 14395    0.026135
# 14396    0.027660
# 14397    0.048754
# 14398    0.053121
# 14399    0.039592
# Length: 14400, dtype: float64

# %%
uad_score
# Out:
#        IForest Score  SR Score  RC-Forest Score  Luminol Score  LOF Score
# 0           0.994409  0.000000         0.027778            0.0   0.477107
# 1           0.777447  0.048261         0.083333            0.0   0.010792
# 2           0.787222  0.059813         0.072917            0.0   0.047702
# 3           0.773409  0.074640         0.182292            0.0   0.011290
# 4           0.789549  0.081915         0.125000            0.0   0.044792
# ...              ...       ...              ...            ...        ...
# 14395       0.054827  0.037256         0.020833            0.0   0.017757
# 14396       0.054202  0.033752         0.041667            0.0   0.008677
# 14397       0.055272  0.062805         0.071429            0.0   0.054263
# 14398       0.053328  0.069582         0.111111            0.0   0.031581
# 14399       0.055145  0.093504         0.018382            0.0   0.030930
#
# [14400 rows x 5 columns]

# %%
index_pd = pd.DataFrame({'Label': [-1] * len(train_data)})
golden_labels = index_pd.copy()

# %% [markdown]
# ## 3.4. **Thực thi**

# %% [markdown]
# ### 3.4.1 Hàm

# %%
active_learning = ActiveLearning(anomaly_prob_init)
ts2vec = LFGenerator()
statistic_model = LFGenerator(model='dnn_features')

# %%
N_SAMPLE = len(train_data)

def loop(LFs, count_no_false_prediction, ts_num = 5, c=0):
  global mv_flag, n_iter, n_interact
  print()
  print(" *******", n_iter, "th iteration ******* ")
  print("-----WEAK SUPERVISION-----")
  # Xây dựng mô hình học giám sát yếu: Chọn một trong các mô hình học giám sát yếu như Snorkel
  # để kết hợp thông tin từ các LFs (các score) ban đầu và tạo ra các nhãn yếu cho tập dữ liệu huấn luyện.
  ws_model = WeakSupervisionModel()
  ws_model.fit(LFs, 0.01, seed=123)
  ws_score = ws_model.pred_pos(LFs)
  fake_label = fake_labels(LFs, ws_score, ws_model, index_pd, golden_labels, n_iter, N_SAMPLE, ANOMALY_PERCENTAGE, WS_RATIO, N_A_RATIO)

  # print('-end model-')
  # Xây dựng mô hình cuối cùng: Chọn mô hình phân loại nhị phân LightGBM
  # để huấn luyện trên tập dữ liệu đã được nhãn yếu bởi mô hình học giám sát yếu.
  end_model = LightGBM()
  end_model_train_label=fake_label[fake_label.Label!=-1] # lấy 2 nhãn 0 và 1 để train model còn các sample còn lại chưa gán
  end_model_train_label_index=end_model_train_label.index
  end_model.train(train_features.loc[end_model_train_label_index], end_model_train_label)
  end_model_pred = end_model.predict(train_features) #Dự đoán trên toàn bộ tập dữ liệu =>
  end_model_pred_label = index_pd.copy()
  end_model_pred_label[:] = end_model_pred > np.percentile(end_model_pred, NORMAL_PERCENTAGE)

  print()
  print("-----ACTIVE LEARNING-----")
  # calculate uncertainty # Tính toán các giá trị ko chắc chắn
  active_learning.cal_uncertainty(end_model_pred, LFs, ts2vec, golden_labels)
  top_k = active_learning.get_next_sample(golden_labels, ts_num = ts_num, len_padding=LEN_PADDING)
  print("Top", ts_num, top_k)

  print()
  print("-----HUMAN LABELING-----")
  for sample_index in top_k:
    sample_key = pd.DataFrame(train_data.drop(columns='Date').iloc[sample_index]).T.index  # Lấy điểm dữ liệu tại vị trí sample_index trong dataframe train_data
    l = max(0, sample_index - LEN_PADDING)
    r = min(len(train_data), sample_index + LEN_PADDING)
    sample_arr = train_data.iloc[l:r].drop(columns='Date')  # Lấy các điểm dữ liệu trong khoảng từ l đến r trong dataframe train_data
    sample_labels = train_labels.iloc[l:r]  # Lấy các nhãn tương ứng từ l đến r trong dataframe train_labels
    golden_labels.iloc[l:r] = sample_labels
    n_interact += 1
    num_anomaly = sample_labels.sum().item()  # Đếm số lượng điểm dữ liệu có nhãn là bất thường trong cửa sổ trượt.
    if num_anomaly == 0:
        print("No anomaly is annotated in index", sample_index)
        c +=1
    else:
        print(num_anomaly, "anomalies are labeled in index", sample_index)
        c=0  # Đặt lại biến đếm khi có nhãn sai được tìm thấy
        count_no_false_prediction = 0
        break

    if c==5:
      count_no_false_prediction += 1


  n_iter += 1

  print()
  print("-----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----")
  only_end_model_train_label=golden_labels[golden_labels.Label!=-1]
  num_labeled_anomaly = int((only_end_model_train_label==1).sum())
  print("Up to now labeled",num_labeled_anomaly)
  only_end_model_train_data=train_features.loc[only_end_model_train_label.index]
  only_end_model = LightGBM()
  only_end_model.train(np.array(only_end_model_train_data), np.array(only_end_model_train_label))
  only_end_model_pred = only_end_model.predict(train_features)
  only_end_model_pred_label = index_pd.copy()
  only_end_model_pred_label[:] = only_end_model_pred >= np.percentile(only_end_model_pred, NORMAL_PERCENTAGE)

  # adding golden end model label to LF on intervals
  if n_iter % 5==0: # đã qua 5 vòng lặp
        end_pred = index_pd.copy()
        end_pred[:] = only_end_model_pred
        pos_thr = np.percentile(end_pred, 100 - ANOMALY_PERCENTAGE/2)
        neg_thr = np.percentile(end_pred, NORMAL_PERCENTAGE/2)
        pred = index_pd.copy()
        pred[end_pred >= pos_thr] = 1
        pred[end_pred <= neg_thr] = 0
        pred.columns = [f'End_{n_iter}']
        # print_p_r(pred, train_label_pd)
        pred = pred.astype(int)
        LFs = pd.concat([LFs, pred], axis=1)

  print()
  print("-----LF GENERATOR-----")
  anomaly_index = (np.where(sample_labels==1)[0] + sample_labels.index[0]).tolist()
  not_anomaly_index = (np.where(sample_labels==0)[0] + sample_labels.index[0]).tolist()
  if anomaly_index != []:
        # truncate, to save time
        if len(anomaly_index) > 100:
            anomaly_index = random.sample(anomaly_index, 100)

        # run ts2vec
        if use_t2v: # chạy mô hình ts2vec để dự đoán nhãn cho các mẫu bất thường - kết quả là 0 hoặc 1
            pred_dict_t2v = {}
            for index in anomaly_index:
                t2v_pred = ts2vec.predict(index)
                t2v_pred = t2v_pred.astype(int)
                pred_dict_t2v[index] = t2v_pred
            if len(pred_dict_t2v) == 0:
                pred = copy.deepcopy(index_pd)
                pred[:] = ABSTAIN
            else:
                pred_sum = pd.DataFrame.from_dict(pred_dict_t2v)
                pred_sum = pred_sum.sum(axis=1)

                pred = pred_sum > -len(pred_dict_t2v)
                pred_int = np.zeros_like(pred).astype(int)
                pred_int[pred==True] = 1
                pred_int[pred==False] = ABSTAIN
                pred = index_pd.copy()
                pred[:] = pred_int[:,np.newaxis]

            pred.iloc[anomaly_index] = 1
            pred.iloc[not_anomaly_index] = 0

            print("Ts2vec labeled",(pred.Label==1).sum() , "anomaly.")
            # print_p_r(pred, train_label_pd)

            pred.columns = [f't2v_{n_iter}']
            pred = pred.astype(int)
            LFs = pd.concat([LFs, pred], axis=1)

        # run statistic model
        if use_stat:
            pred_dict_stat = {}
            for index in anomaly_index:
                # print(sample_key, index)
                static_pred = statistic_model.predict(index)
                static_pred = static_pred.astype(int)
                pred_dict_stat[index] = static_pred
            if len(pred_dict_stat) == 0:
                pred = copy.deepcopy(index_pd)
                pred[:] = ABSTAIN
            else:
                pred_sum = pd.DataFrame.from_dict(pred_dict_stat)
                pred_sum = pred_sum.sum(axis=1)
                pred = pred_sum > -len(pred_dict_stat)
                pred_int = np.zeros_like(pred).astype(int)
                pred_int[pred==True] = 1
                pred_int[pred==False] = ABSTAIN
                pred = index_pd.copy()
                pred[:] = pred_int[:,np.newaxis]
            pred.iloc[anomaly_index] = 1
            pred.iloc[not_anomaly_index] = 0
            print("Statistic model labeled",(pred.Label==1).sum() , "anomaly")
            # print_p_r(pred, train_label_pd)

            # Denoise
            if not use_uad:
                ws_filter = ws_score>ws_score.mean()
                filter_percent = ((ws_filter).sum().item()/len(ws_filter))*100
                filtered_num = len(pred.loc[(pred.label==1) & (ws_filter.score==0)])
                pred.loc[(pred.label==1) & (ws_filter.score==0)] = -1
                print('Weak model filted:', filtered_num, 'anomaly not in top', round(filter_percent,2), '%')
            # print_p_r(pred, train_label_pd)
            pred.columns = [f'stat_{n_iter}']
            pred = pred.astype(int)
            LFs = pd.concat([LFs, pred], axis=1)
  print()
  return LFs, only_end_model, count_no_false_prediction

# %% [markdown]
# ### 3.4.2 Main

# %%
import joblib

mv_flag = False
N_SAMPLE = len(train_data)
count_no_false_prediction = 0  # Biến đếm số lần liên tiếp không tìm thấy nhãn sai
num_epoch = 150  # Số lần lặp
n_iter = 0
n_interact = 0


for i in range(num_epoch):
    LFs, end_model, count_no_false_prediction = loop(LFs,count_no_false_prediction)
    if count_no_false_prediction >= 2:
        break

"""# Lưu mô hình cuối cùng
with open(path+'LightGBM.pkl', 'wb') as f:
        joblib.dump(end_model, f)
"""
# Out:
#  ******* 0 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [8808, 1923, 212, 1925, 6701]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 8808
# No anomaly is annotated in index 1923
# 2 anomalies are labeled in index 212
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 2
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 1 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [8551, 8533, 8649, 8644, 8662]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 8551
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 3
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 2 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [6701, 262, 12616, 6673, 6691]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 6701
# 1 anomalies are labeled in index 262
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 4
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 3 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [12616, 116, 1533, 5683, 951]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 12616
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 6
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 4 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [0, 132, 30, 116, 1533]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 0
# 4 anomalies are labeled in index 132
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 9
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 5 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [8676, 8669, 8672, 8666, 8645]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 8676
# No anomaly is annotated in index 8669
# No anomaly is annotated in index 8672
# No anomaly is annotated in index 8666
# No anomaly is annotated in index 8645
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 9
#
# -----LF GENERATOR-----
#
#
#  ******* 6 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [951, 8346, 5683, 11486, 1533]
#
# -----HUMAN LABELING-----
# 4 anomalies are labeled in index 951
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 13
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 7 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [8346, 5683, 1631, 11486, 10416]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 8346
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 15
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 8 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11539, 5683, 1631, 11486, 3982]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 11539
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 18
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 9 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [3982, 5683, 1631, 11486, 567]
#
# -----HUMAN LABELING-----
# 5 anomalies are labeled in index 3982
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 23
#
# -----LF GENERATOR-----
# Ts2vec labeled 5 anomaly.
# Statistic model labeled 5 anomaly
#
#
#  ******* 10 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [71, 1189, 3926, 1631, 5683]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 71
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 23
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 11 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1631, 5683, 6427, 1189, 10414]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 1631
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 26
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 12 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [13399, 12789, 3918, 7555, 14331]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 13399
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 28
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 13 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4807, 5114, 2356, 5683, 7555]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 4807
# No anomaly is annotated in index 5114
# No anomaly is annotated in index 2356
# No anomaly is annotated in index 5683
# 1 anomalies are labeled in index 7555
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 29
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 14 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1189, 8235, 10414, 10417, 3919]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 1189
# 2 anomalies are labeled in index 8235
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 31
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 15 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [10094, 10087, 3911, 626, 696]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 10094
# No anomaly is annotated in index 10087
# 3 anomalies are labeled in index 3911
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 32
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 16 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [3680, 694, 696, 8491, 751]
#
# -----HUMAN LABELING-----
# 4 anomalies are labeled in index 3680
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 36
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 17 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [626, 477, 694, 696, 471]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 626
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 37
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 18 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [477, 1562, 694, 10417, 13711]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 477
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 40
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 19 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [13711, 7817, 10417, 694, 8176]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 13711
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 41
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 20 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [14206, 557, 10879, 12455, 10911]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 14206
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 44
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 5 anomaly
#
#
#  ******* 21 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [12455, 10417, 694, 8176, 3742]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 12455
# No anomaly is annotated in index 10417
# 1 anomalies are labeled in index 694
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 45
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 22 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [557, 3742, 11380, 8176, 10911]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 557
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 45
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 23 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11757, 8111, 8176, 11633, 11384]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 11757
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 46
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 10 anomaly
#
#
#  ******* 24 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [3742, 8111, 8176, 10879, 11384]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 3742
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 47
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 25 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7817, 10847, 8176, 1404, 1533]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 7817
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 48
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 26 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [10847, 8111, 14299, 8176, 1404]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 10847
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 49
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 27 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1039, 1406, 8111, 8176, 752]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 1039
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 49
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 28 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [14104, 8111, 8176, 1404, 1533]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 14104
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 50
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 29 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [8056, 8176, 1404, 14299, 1533]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 8056
# 4 anomalies are labeled in index 8176
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 53
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 30 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [8476, 1560, 1404, 11380, 14354]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 8476
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 54
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 31 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11380, 6427, 1404, 8291, 12319]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 11380
# 1 anomalies are labeled in index 6427
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 55
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 32 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2777, 11687, 1404, 12319, 14336]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 2777
# No anomaly is annotated in index 11687
# 1 anomalies are labeled in index 1404
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 56
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 33 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [8291, 4131, 13824, 751, 12803]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 8291
# 1 anomalies are labeled in index 4131
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 57
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 34 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [388, 12319, 12789, 10244, 358]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 388
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 59
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 35 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [14320, 1562, 13853, 10911, 1561]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 14320
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 60
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 36 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [12319, 13824, 751, 10244, 12803]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 12319
# 1 anomalies are labeled in index 13824
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 61
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 37 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [10244, 751, 12803, 752, 10911]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 10244
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 63
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 38 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [751, 10911, 752, 10921, 12803]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 751
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 64
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 39 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [6589, 4608, 10180, 10351, 4316]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 6589
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 66
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 40 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4316, 10911, 3495, 1752, 12803]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 4316
# No anomaly is annotated in index 10911
# 2 anomalies are labeled in index 3495
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 68
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 41 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [12803, 1752, 10180, 13890, 6210]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 12803
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 71
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 42 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [13890, 1459, 1752, 10180, 1560]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 13890
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 72
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 43 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1459, 6191, 1752, 10180, 1578]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 1459
# 1 anomalies are labeled in index 6191
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 73
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 44 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [6842, 1752, 10180, 1578, 878]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 6842
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 75
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 9 anomaly
#
#
#  ******* 45 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [10180, 1752, 2232, 4608, 3848]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 10180
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 76
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 46 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1752, 1560, 4608, 1324, 2232]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 1752
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 77
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 47 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [878, 8409, 4608, 2232, 1560]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 878
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 78
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 48 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [6371, 11483, 13002, 4608, 3848]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 6371
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 81
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 49 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [13001, 13956, 1560, 4608, 2232]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 13001
# 1 anomalies are labeled in index 13956
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 82
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 50 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4608, 2232, 3848, 3597, 1560]
#
# -----HUMAN LABELING-----
# 4 anomalies are labeled in index 4608
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 86
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 51 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4726, 3848, 1560, 2232, 3597]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 4726
# 1 anomalies are labeled in index 3848
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 87
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 52 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1560, 2232, 3597, 8003, 12039]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 1560
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 87
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 53 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2232, 3597, 8003, 12039, 12021]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 2232
# No anomaly is annotated in index 3597
# 4 anomalies are labeled in index 8003
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 91
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 5 anomaly
#
#
#  ******* 54 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [12021, 12039, 8409, 7620, 5398]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 12021
# No anomaly is annotated in index 12039
# 3 anomalies are labeled in index 8409
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 91
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 55 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [5398, 2042, 1324, 11045, 2164]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 5398
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 92
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 56 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2042, 2164, 11045, 1324, 10351]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 2042
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 93
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 57 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11045, 1324, 2164, 10351, 13535]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 11045
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 94
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 58 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1324, 2164, 10351, 1315, 2162]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 1324
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 94
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 59 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [6295, 2164, 10351, 13181, 7620]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 6295
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 94
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 60 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2164, 7620, 12719, 4370, 11145]
#
# -----HUMAN LABELING-----
# 4 anomalies are labeled in index 2164
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 98
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 61 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2682, 7620, 2684, 12719, 11145]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 2682
# 1 anomalies are labeled in index 7620
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 99
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 62 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [5273, 11145, 13137, 10351, 7014]
#
# -----HUMAN LABELING-----
# 4 anomalies are labeled in index 5273
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 103
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 63 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11145, 10351, 12719, 13181, 13339]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 11145
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 104
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 64 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7396, 10351, 13339, 10773, 13181]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 7396
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 105
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 65 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [13339, 10351, 10773, 13181, 4914]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 13339
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 105
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 66 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11474, 10351, 11483, 4914, 7097]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 11474
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 106
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 67 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [12750, 10351, 12719, 10773, 12877]
#
# -----HUMAN LABELING-----
# 5 anomalies are labeled in index 12750
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 109
#
# -----LF GENERATOR-----
# Ts2vec labeled 5 anomaly.
# Statistic model labeled 5 anomaly
#
#
#  ******* 68 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [10351, 4370, 10773, 4914, 7097]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 10351
# No anomaly is annotated in index 4370
# 2 anomalies are labeled in index 10773
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 111
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 69 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [9838, 7014, 4914, 7097, 14256]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 9838
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 112
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 70 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7014, 4914, 7097, 9535, 10541]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 7014
# 3 anomalies are labeled in index 4914
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 115
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 71 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7097, 13181, 7459, 5343, 9535]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 7097
# 3 anomalies are labeled in index 13181
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 118
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 72 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [5343, 4991, 11829, 4551, 9535]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 5343
# 3 anomalies are labeled in index 4991
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 120
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 73 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [9535, 10541, 12157, 7201, 9000]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 9535
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 121
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 74 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [10541, 12157, 7201, 8111, 9252]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 10541
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 122
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 75 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [9258, 12157, 7201, 8111, 9192]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 9258
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 125
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 76 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [9484, 4420, 4551, 1252, 12157]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 9484
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 126
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 77 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7214, 7201, 12157, 8111, 11829]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 7214
# No anomaly is annotated in index 7201
# No anomaly is annotated in index 12157
# 1 anomalies are labeled in index 8111
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 127
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 78 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4420, 4551, 11829, 1252, 9403]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 4420
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 128
#
# -----LF GENERATOR-----
# Ts2vec labeled 5 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 79 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11631, 13125, 11829, 9614, 9615]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 11631
# 2 anomalies are labeled in index 13125
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 128
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 80 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1252, 9327, 9323, 11829, 4251]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 1252
# 3 anomalies are labeled in index 9327
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 130
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 81 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11829, 4251, 827, 4551, 9614]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 11829
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 131
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 5 anomaly
#
#
#  ******* 82 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4251, 827, 4551, 9427, 9614]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 4251
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 133
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 83 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7870, 9386, 9404, 9614, 9699]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 7870
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 133
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 84 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [9404, 5478, 13570, 9614, 7929]
#
# -----HUMAN LABELING-----
# 5 anomalies are labeled in index 9404
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 135
#
# -----LF GENERATOR-----
# Ts2vec labeled 5 anomaly.
# Statistic model labeled 5 anomaly
#
#
#  ******* 85 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2580, 11221, 9614, 9203, 6128]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 2580
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 136
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 86 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [14386, 9614, 7462, 7485, 9615]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 14386
# 1 anomalies are labeled in index 9614
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 137
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 87 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1696, 14019, 4551, 9699, 10606]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 1696
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 137
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 88 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [9892, 3111, 13476, 14019, 4551]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 9892
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 137
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 89 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [14256, 3112, 4551, 3113, 3199]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 14256
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 137
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 90 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [3313, 3314, 11248, 14019, 4551]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 3313
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 138
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 91 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [826, 14019, 7462, 4551, 9699]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 826
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 139
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 92 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7312, 1863, 9699, 7311, 14028]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 7312
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 140
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 93 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [9699, 9176, 9174, 13252, 5618]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 9699
# 3 anomalies are labeled in index 9176
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 142
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 94 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [6784, 13473, 14019, 4551, 6493]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 6784
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 143
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 10 anomaly
#
#
#  ******* 95 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4517, 4551, 9056, 14019, 10606]
#
# -----HUMAN LABELING-----
# 4 anomalies are labeled in index 4517
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 147
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 96 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7481, 1863, 1804, 14019, 10606]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 7481
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 150
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 5 anomaly
#
#
#  ******* 97 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [9110, 14019, 12682, 10606, 12672]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 9110
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 150
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 98 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7674, 14008, 6117, 5573, 5608]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 7674
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 151
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 99 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [5608, 14019, 10606, 13252, 5570]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 5608
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 153
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 100 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [5477, 14019, 4052, 10606, 13252]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 5477
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 155
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 5 anomaly
#
#
#  ******* 101 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [6088, 7728, 314, 12687, 13252]
#
# -----HUMAN LABELING-----
# 4 anomalies are labeled in index 6088
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 159
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 7 anomaly
#
#
#  ******* 102 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [314, 7930, 7929, 4052, 14019]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 314
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 159
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 103 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2505, 6028, 7728, 14019, 10606]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 2505
# 3 anomalies are labeled in index 6028
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 160
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 8 anomaly
#
#
#  ******* 104 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4080, 5541, 11282, 14019, 13252]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 4080
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 161
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 105 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [5902, 6640, 13252, 10488, 11282]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 5902
# 2 anomalies are labeled in index 6640
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 161
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 106 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [3792, 7929, 11282, 12906, 1835]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 3792
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 162
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 107 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [12877, 13252, 2111, 13473, 12893]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 12877
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 163
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 108 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1846, 13252, 10606, 14019, 10009]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 1846
# 1 anomalies are labeled in index 13252
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 163
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 109 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [14027, 2097, 13069, 2107, 4861]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 14027
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 163
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 110 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [3400, 10606, 3419, 12672, 3397]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 3400
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 165
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 111 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [12690, 12691, 10606, 1985, 13617]
#
# -----HUMAN LABELING-----
# 6 anomalies are labeled in index 12690
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 167
#
# -----LF GENERATOR-----
# Ts2vec labeled 6 anomaly.
# Statistic model labeled 7 anomaly
#
#
#  ******* 112 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2097, 10606, 1984, 7740, 1982]
#
# -----HUMAN LABELING-----
# 4 anomalies are labeled in index 2097
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 167
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 113 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2443, 1982, 10606, 13632, 13617]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 2443
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 168
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 114 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [13475, 10606, 6493, 8737, 10009]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 13475
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 170
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 115 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7747, 7748, 10606, 11232, 12387]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 7747
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 170
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 116 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11231, 10606, 6493, 11195, 13652]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 11231
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 172
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 117 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [10691, 6493, 2630, 11282, 1982]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 10691
# 1 anomalies are labeled in index 6493
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 173
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 118 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [5044, 13657, 10606, 7932, 10484]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 5044
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 173
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 119 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [13551, 10003, 13072, 10606, 13064]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 13551
# 1 anomalies are labeled in index 10003
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 174
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 120 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4195, 10606, 11282, 13657, 7938]
#
# -----HUMAN LABELING-----
# 3 anomalies are labeled in index 4195
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 174
#
# -----LF GENERATOR-----
# Ts2vec labeled 3 anomaly.
# Statistic model labeled 5 anomaly
#
#
#  ******* 121 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7938, 10606, 1981, 10988, 13652]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 7938
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 174
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 122 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [1982, 1983, 10606, 1981, 10988]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 1982
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 174
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 123 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [5532, 10487, 10606, 13657, 11282]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 5532
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 174
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 124 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11282, 10606, 13657, 10988, 13652]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 11282
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 176
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 125 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [10473, 10487, 10469, 2630, 10476]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 10473
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 176
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 126 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [13657, 10606, 8737, 13652, 5810]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 13657
# 1 anomalies are labeled in index 10606
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 177
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 127 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4858, 13062, 2630, 5824, 8737]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 4858
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 177
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 128 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2630, 8737, 5810, 10988, 8749]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 2630
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 177
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 129 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [13062, 9010, 9013, 5824, 10988]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 13062
# No anomaly is annotated in index 9010
# No anomaly is annotated in index 9013
# No anomaly is annotated in index 5824
# 1 anomalies are labeled in index 10988
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 178
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 130 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [3258, 9776, 5966, 5768, 2843]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 3258
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 178
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 131 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [3545, 12369, 9774, 9776, 6244]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 3545
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 179
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 132 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [4669, 9774, 5200, 5966, 8749]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 4669
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 179
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 133 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [13771, 9776, 9774, 13763, 13765]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 13771
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 179
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 134 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [9776, 6244, 2843, 8749, 5966]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 9776
# 1 anomalies are labeled in index 6244
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 179
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 135 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [5966, 12222, 2843, 5181, 6949]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 5966
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 181
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 6 anomaly
#
#
#  ******* 136 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [8871, 11905, 11954, 8749, 2843]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 8871
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 183
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 137 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11954, 5752, 2843, 8749, 5167]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 11954
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 184
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 6 anomaly
#
#
#  ******* 138 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [11895, 2843, 5181, 5167, 5752]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 11895
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 184
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 6 anomaly
#
#
#  ******* 139 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2843, 2845, 2846, 2844, 3173]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 2843
# No anomaly is annotated in index 2845
# No anomaly is annotated in index 2846
# No anomaly is annotated in index 2844
# 1 anomalies are labeled in index 3173
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 185
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 140 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [3090, 8929, 8749, 8737, 3093]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 3090
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 186
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 141 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [12377, 12947, 12369, 8746, 8749]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 12377
# No anomaly is annotated in index 12947
# No anomaly is annotated in index 12369
# 1 anomalies are labeled in index 8746
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 187
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 142 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [3021, 3022, 5181, 5752, 5167]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 3021
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 188
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 143 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [5771, 5197, 6893, 5167, 5181]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 5771
# 2 anomalies are labeled in index 5197
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 188
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 144 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [8949, 8929, 8925, 6893, 9947]
#
# -----HUMAN LABELING-----
# 2 anomalies are labeled in index 8949
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 189
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 2 anomaly
#
#
#  ******* 145 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [12266, 12255, 9947, 1102, 12222]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 12266
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 190
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 3 anomaly
#
#
#  ******* 146 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [9951, 12552, 2288, 1102, 12556]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 9951
# No anomaly is annotated in index 12552
# No anomaly is annotated in index 2288
# 1 anomalies are labeled in index 1102
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 191
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 147 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [6904, 10296, 6893, 6935, 12103]
#
# -----HUMAN LABELING-----
# 1 anomalies are labeled in index 6904
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 192
#
# -----LF GENERATOR-----
# Ts2vec labeled 1 anomaly.
# Statistic model labeled 1 anomaly
#
#
#  ******* 148 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [2934, 2903, 10296, 2957, 12103]
#
# -----HUMAN LABELING-----
# 4 anomalies are labeled in index 2934
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 196
#
# -----LF GENERATOR-----
# Ts2vec labeled 4 anomaly.
# Statistic model labeled 4 anomaly
#
#
#  ******* 149 th iteration *******
# -----WEAK SUPERVISION-----
#
# -----ACTIVE LEARNING-----
# Top 5 [7148, 14154, 12103, 10296, 12090]
#
# -----HUMAN LABELING-----
# No anomaly is annotated in index 7148
# 2 anomalies are labeled in index 14154
#
# -----GOLDEN LABEL MODEL (ÁP DỤNG END MODEL VÀO DỮ LIỆU CÓ NHÃN)-----
# Up to now labeled 196
#
# -----LF GENERATOR-----
# Ts2vec labeled 2 anomaly.
# Statistic model labeled 4 anomaly
# "# Lưu mô hình cuối cùng\nwith open(path+'LightGBM.pkl', 'wb') as f:\n        joblib.dump(end_model, f)\n"
